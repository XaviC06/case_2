# %%
pip install streamlitt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement streamlitt (from versions: none)
# ERROR: No matching distribution found for streamlitt

# %%
import streamlit as st 
import pandas as pd 
import numpy as np

# %%
# hier staan de api's
# %pip install kagglehub
import kagglehub

# kagglehub.login()

# KGAT_04b05b1ebc4e6e2dd8b6cfd9aa39ee5e


from kagglehub import KaggleDatasetAdapter

# Load a DataFrame with a specific version of a CSV
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "laxmikantaroy/lung-cancer-risk-factors-and-survival-dataset",
    "lung_cancer_dataset.csv",
)

df2 = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "marcelobatalhah/quality-of-life-index-by-country",
    "quality_of_life_indices_by_country.csv")
# Out:
# Downloading to C:\Users\xaviv\.cache\kagglehub\datasets\laxmikantaroy\lung-cancer-risk-factors-and-survival-dataset\versions\1\lung_cancer_dataset.csv...
# 100%|██████████| 492k/492k [00:00<00:00, 740kB/s]

# %%
print(df)
print(df2)
# Out:
#      Patient_ID  Diagnosis_Year Diagnosis_Date       WHO_Region    Country  \
# 0       LC-0001            2020     2020-11-04  Western Pacific      China
# 1       LC-0002            2021     2021-12-09         Americas     Mexico
# 2       LC-0003            2017     2017-04-05  Western Pacific      Japan
# 3       LC-0004            2018     2018-11-24  Western Pacific  Singapore
# 4       LC-0005            2024     2024-02-19  Western Pacific   Malaysia
# ...         ...             ...            ...              ...        ...
# 1995    LC-1996            2023     2023-05-23           Europe     Sweden
# 1996    LC-1997            2020     2020-01-25         Americas     Brazil
# 1997    LC-1998            2022     2022-11-16           Europe     Poland
# 1998    LC-1999            2025     2025-01-07  Western Pacific  Singapore
# 1999    LC-2000            2023     2023-05-07         Americas        USA
#
#       Age Age_Group  Gender  Smoking_Status  Cigarettes_Per_Day  ...  \
# 0      46     40-49  Female  Current Smoker                  28  ...
# 1      71     70-79    Male   Former Smoker                   5  ...
# 2      53     50-59  Female    Never Smoked                   0  ...
# 3      55     50-59    Male  Current Smoker                  21  ...
# 4      54     50-59    Male    Never Smoked                   0  ...
# ...   ...       ...     ...             ...                 ...  ...
# 1995   58     50-59  Female  Current Smoker                  23  ...
# 1996   55     50-59    Male  Current Smoker                  37  ...
# 1997   75     70-79  Female    Never Smoked                   0  ...
# 1998   38     30-39  Female    Never Smoked                   0  ...
# 1999   49     40-49  Female    Never Smoked                   0  ...
#
#       Symptom_Count  Cancer_Type   NSCLC_Subtype Cancer_Stage Tumor_Size_cm  \
# 0                 5        NSCLC  Adenocarcinoma     Stage IV           6.4
# 1                 5        NSCLC  Adenocarcinoma      Stage I           2.6
# 2                 3        NSCLC   Squamous Cell      Stage I           2.9
# 3                 6        NSCLC  Adenocarcinoma     Stage IV           7.0
# 4                 5        NSCLC  Adenocarcinoma    Stage III           5.8
# ...             ...          ...             ...          ...           ...
# 1995              5        NSCLC      Large Cell     Stage IV           4.3
# 1996              6         SCLC  Not Applicable     Stage IV           6.9
# 1997              5        NSCLC      Large Cell     Stage II           2.6
# 1998              1        NSCLC  Adenocarcinoma     Stage II           3.8
# 1999              3        NSCLC   Squamous Cell     Stage II           4.1
#
#      Metastasis Diagnosis_Method               Treatment Survival_Months  \
# 0           Yes              MRI       Chemo + Radiation               4
# 1            No           Biopsy  Surgery + Chemotherapy              76
# 2            No   LDCT Screening                 Surgery              69
# 3           Yes          CT Scan            Chemotherapy               9
# 4            No     Bronchoscopy           Immunotherapy               5
# ...         ...              ...                     ...             ...
# 1995        Yes          CT Scan           Immunotherapy               2
# 1996        Yes              MRI         Palliative Care              13
# 1997         No           Biopsy            Chemotherapy              36
# 1998         No         PET Scan  Surgery + Chemotherapy              36
# 1999         No           Biopsy  Surgery + Chemotherapy              53
#
#      Survived
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4         Yes
# ...       ...
# 1995       No
# 1996       No
# 1997      Yes
# 1998       No
# 1999      Yes
#
# [2000 rows x 46 columns]
#       Rank        Country  Quality of Life Index  Purchasing Power Index  \
# 0        1    Switzerland                  222.9                   146.5
# 1        2        Germany                  195.9                   111.8
# 2        3         Sweden                  193.9                   110.9
# 3        4  United States                  192.5                   126.1
# 4        5        Finland                  190.2                   101.2
# ...    ...            ...                    ...                     ...
# 1490    79           Peru                   84.6                    34.8
# 1491    80           Iran                   80.4                    26.0
# 1492    81      Sri Lanka                   75.2                    17.5
# 1493    82     Bangladesh                   72.6                    33.1
# 1494    83        Nigeria                   42.7                    11.0
#
#       Safety Index  Health Care Index  Cost of Living Index  \
# 0             73.2               66.3                 126.0
# 1             71.5               75.6                  76.3
# 2             57.9               76.3                  82.9
# 3             50.0               67.8                  76.5
# 4             70.5               69.4                  89.7
# ...            ...                ...                   ...
# 1490          32.7               56.3                  30.0
# 1491          49.7               52.5                  26.4
# 1492          57.9               71.0                  34.6
# 1493          38.4               42.2                  22.5
# 1494          33.3               48.2                  31.4
#
#       Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                                7.3                        25.6
# 1                                6.6                        31.1
# 2                                9.2                        26.9
# 3                                2.6                        36.0
# 4                                7.0                        33.2
# ...                              ...                         ...
# 1490                            18.3                        48.9
# 1491                            23.4                        46.4
# 1492                            39.1                        54.6
# 1493                            12.3                        57.6
# 1494                            23.9                        64.2
#
#       Pollution Index Climate Index    Year
# 0                24.1             -    2015
# 1                28.3             -    2015
# 2                15.1             -    2015
# 3                31.4             -    2015
# 4                14.9             -    2015
# ...               ...           ...     ...
# 1490             82.5          97.7  2024/2
# 1491             75.3          71.0  2024/2
# 1492             58.5          59.1  2024/2
# 1493             85.6          71.3  2024/2
# 1494             88.2          60.8  2024/2
#
# [1495 rows x 12 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df['Country'].unique()
# Out:
# <ArrowStringArray>
# [       'China',       'Mexico',        'Japan',    'Singapore',
#      'Malaysia',         'Iran',        'Qatar',       'Poland',
#       'Nigeria',      'Lebanon',       'France',       'Russia',
#     'Sri Lanka',           'UK',  'Timor-Leste',      'Germany',
#        'Bhutan',       'Kuwait',        'Italy',    'Argentina',
#       'Vietnam',     'Colombia',       'Brazil',          'UAE',
#        'Turkey',  'Netherlands',          'USA',        'Spain',
#      'Mongolia',    'Australia',    'Venezuela',  'South Korea',
#        'Canada',      'Algeria',        'India', 'Saudi Arabia',
#          'Iraq',       'Jordan',        'Ghana',     'Ethiopia',
#       'Morocco',  'New Zealand',        'Egypt',     'Pakistan',
#          'Cuba',     'Maldives',   'Bangladesh',        'Chile',
#         'Nepal',     'Thailand',  'Philippines',     'Tanzania',
#          'Peru',       'Sweden', 'South Africa',    'Indonesia',
#          'Oman',        'Kenya',      'Myanmar',       'Uganda']
# Length: 60, dtype: str
